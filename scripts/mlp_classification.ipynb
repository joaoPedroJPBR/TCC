# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ler o arquivo CSV com as colunas na primeira linha
df = pd.read_csv('../data/diabetes_prediction_weka.csv')

# %%
# 2. Converta todos os atributos não numéricos em numéricos
le = preprocessing.LabelEncoder()
for column in df.columns:
    if df[column].dtype == type(object):
        df[column] = le.fit_transform(df[column])

# %%
# 3. Separe as entradas (X) e a classe (y)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
# 4. Divida os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 5. Treine a MLP
clf = MLPClassifier(max_iter=1000, random_state=42)
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=1000, random_state=42)

# %%
# 6. Faça as previsões
y_pred = clf.predict(X_test)

# %%
# 7. Imprima a acurácia e a matriz de confusão
print("Acurácia:", accuracy_score(y_test, y_pred))
print("Matriz de Confusão:\n", confusion_matrix(y_test, y_pred))
# Out:
# Acurácia: 0.9182539682539682
# Matriz de Confusão:
#  [[24691  2592]
#  [ 1528 21589]]

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
# Criar um plot da matriz de confusão usando seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Classe 0', 'Classe 1'], yticklabels=['Classe 0', 'Classe 1'])
plt.xlabel('Previsões')
plt.ylabel('Real')
plt.title('Matriz de Confusão model MLP_Classification')
plt.show()

# %%
# Calcular o índice kappa
kappa = cohen_kappa_score(y_test, y_pred)

# Imprimir o índice kappa
print("Índice Kappa:", kappa)
# Out:
# Índice Kappa: 0.8359596430322949

# %% [markdown]
# Aplicando outras métricas

# %% [markdown]
# 1 - Precisão

# %%
precision = precision_score (y_test , y_pred)
print("Precisão:", precision)
# Out:
# Precisão: 0.8928084032918407

# %% [markdown]
# 2 - Sensibilidade

# %%
sensitivity = recall_score(y_test, y_pred)
print("Sensibilidade:", sensitivity)
# Out:
# Sensibilidade: 0.9339014578016178

# %% [markdown]
# 3 - Especificidade

# %%
#true negatives
TN = cm[0][0]
#false positives
FP = cm[0][1]

specificity = TN/(TN+FP)
print("Especificidade:", specificity)
# Out:
# Especificidade: 0.9049957849210131
